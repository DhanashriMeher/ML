# %% [markdown]
# # Regression Benchmark

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importing dataset
data=pd.read_csv('fifa_eda.csv')
data
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
data.shape
# Out:
# (18207, 18)

# %%
data.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
data.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %% [markdown]
# # Shuffling and creating Train and Test set

# %%
from sklearn.utils import shuffle

# %%
#shuffling dataset
data=shuffle(data,random_state=42)
data
# Out:
#            ID           Name  Age          Nationality  Overall  Potential  \
# 5848   229692        J. Huth   24              Germany       69         77
# 14634  239605      M. Diallo   27              Senegal       61         61
# 11807  214981   E. Mastrolía   27            Argentina       64         68
# 5826   189235     J. Hegeler   30              Germany       69         69
# 1989   204497      K. Stöger   24              Austria       75         80
# ...       ...            ...  ...                  ...      ...        ...
# 11284  209475  J. O'Sullivan   24  Republic of Ireland       64         67
# 11964  220649     S. Vecchia   23               Sweden       64         72
# 5390   222391      J. Minala   21             Cameroon       70         76
# 860    178085        Granero   30                Spain       78         78
# 15795  231411    R. McKenzie   19              England       59         74
#
#                          Club   Value  Wage Preferred Foot  \
# ...

# %%
#creating 4 divisions
div =int(data.shape[0]/4)
div
# Out:
# 4551

# %%
# 3 parts to train set and 1 part to test set
train =data.loc[:3*div+1,:]
test =data.loc[3*div+1:]

# %%
train.head()
# Out:
#            ID          Name  Age Nationality  Overall  Potential  \
# 5848   229692       J. Huth   24     Germany       69         77
# 14634  239605     M. Diallo   27     Senegal       61         61
# 11807  214981  E. Mastrolía   27   Argentina       64         68
# 5826   189235    J. Hegeler   30     Germany       69         69
# 1989   204497     K. Stöger   24     Austria       75         80
#
#                          Club   Value  Wage Preferred Foot  \
# 5848          1. FSV Mainz 05  1200.0   8.0          Right
# 14634               KAS Eupen   270.0   2.0          Right
# 11807  Club Atlético Talleres   400.0   3.0           Left
# 5826             Bristol City   775.0  18.0          Right
# 1989       Fortuna Düsseldorf  9000.0  24.0           Left
#
#        International Reputation  Skill Moves Position  Joined  \
# 5848                        1.0          1.0       GK    2015
# 14634                       1.0          2.0       ST    2017
# ...

# %%
test.head()
# Out:
#            ID         Name  Age Nationality  Overall  Potential  \
# 13654  186539    B. Kukeli   34     Albania       62         62
# 13400  244575   A. Sánchez   19      Mexico       62         73
# 7353   238008   J. Elliott   22     England       68         73
# 1492   171972  J. McArthur   30    Scotland       76         76
# 8383   214695   J. Ampuero   31       Chile       67         67
#
#                      Club   Value  Wage Preferred Foot  \
# 13654             FC Sion   150.0   5.0           Left
# 13400           Cruz Azul   450.0   2.0          Right
# 7353   Philadelphia Union  1000.0   3.0          Right
# 1492       Crystal Palace  7000.0  48.0          Right
# 8383       Unión Española   525.0   2.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 13654                       1.0          2.0       CM    2017
# 13400                       1.0          2.0       CB    2018
# ...

# %%
data['Preferred Foot'].unique
# Out:
# <bound method Series.unique of 3270     Right
# 16662    Right
# 11538    Right
# 2876     Right
# 11584    Right
#          ...
# 5966     Right
# 15407    Right
# 6778     Right
# 4342      Left
# 12722    Right
# Name: Preferred Foot, Length: 18207, dtype: object>

# %% [markdown]
# #Simple Mean(mean of height)

# %%
#storing simple mean in a new column in the test set as "simple_mean"
test['simple_mean'] =train['Height'].mean()
# Out:
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\1172710254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['simple_mean'] =train['Height'].mean()

# %%
#calculating mean absolute error
from sklearn.metrics import mean_absolute_error as MAE

simple_mean_error = MAE(test['Height'],test['simple_mean'])
simple_mean_error
# Out:
# 0.18104370303905376

# %% [markdown]
# # Mean height with respect to Nationality

# %%
out_type =pd.pivot_table(train,values='Height',index=['Nationality'],aggfunc=np.mean)
out_type
# Out:
#                Height
# Nationality
# Afghanistan  5.750000
# Albania      5.929432
# Algeria      5.947712
# Andorra      6.000000
# Angola       5.877778
# ...               ...
# Uzbekistan   5.958333
# Venezuela    5.884817
# Wales        5.957965
# Zambia       5.845238
# Zimbabwe     5.868056
#
# [158 rows x 1 columns]

# %%
#Initializing new column to zero
test['out_type_mean'] =0

#For every unique entry in outlet_Identifier
for i in train['Nationality'].unique():
#Assign the mean value corresponding to unique entry
    test['out_type_mean'][test['Nationality']==str(i)] = train['Height'][train['Nationality'] == str(i)].mean()
# Out:
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\3038019626.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['out_type_mean'] =0
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\3038019626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['out_type_mean'][test['Nationality']==str(i)] = train['Height'][train['Nationality'] == str(i)].mean()
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\3038019626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#Calculating mean absolute error
out_type_error = MAE(test['Height'],test['out_type_mean'])
out_type_error
# Out:
# 0.18371943097402813

# %% [markdown]
# Mean Item Outlet Sales with respect to joined

# %%
out_year =pd.pivot_table(train,values ='Height',index= ['Joined'],aggfunc =np.mean)
out_year
# Out:
#           Height
# Joined
# 1998    5.722222
# 1999    6.166667
# 2000    6.000000
# 2001    6.333333
# 2002    6.107143
# 2003    5.951389
# 2004    5.888889
# 2005    5.941176
# 2006    6.023810
# 2007    5.866667
# 2008    5.988095
# 2009    5.915385
# 2010    5.968750
# 2011    5.944106
# 2012    5.926421
# 2013    5.954870
# 2014    5.948772
# 2015    5.948452
# 2016    5.946996
# 2017    5.944644
# 2018    5.945808

# %%
#Initializing new column to zero
test['Out_year_mean']=0

#for every unique entry in outlet identifier
for i in train['Joined'].unique():
    #Assign the mean value corresponding to unique entry
    test['Out_year_mean'][test['Joined'] == str(i)]=train['Height'][train['Joined'] == str(i)].mean()
# Out:
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\794639592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Out_year_mean']=0
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\794639592.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Out_year_mean'][test['Joined'] == str(i)]=train['Height'][train['Joined'] == str(i)].mean()
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\794639592.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#Calculating mean absolute error
out_year_error = MAE(test['Height'],test['Out_year_mean'])
out_year_error
# Out:
# 5.950731055641724

# %% [markdown]
# # Height with respect to both Nationality and Joined

# %%
combo=pd.pivot_table(train,values ='Height',index=['Nationality','Joined'])
combo
# Out:
#                       Height
# Nationality Joined
# Afghanistan 2016    5.666667
#             2018    5.833333
# Albania     2008    5.833333
#             2010    5.625000
#             2014    6.083333
# ...                      ...
# Zimbabwe    2011    5.833333
#             2013    6.083333
#             2016    6.166667
#             2017    5.875000
#             2018    5.666667
#
# [851 rows x 1 columns]

# %%
#Initiating new empty column
test['Super_mean']=0

#Assigning variables to strings (to shorten code length)
s2= 'Nationality'
s1= 'Joined'

#for every Unique value in s1
for i in test[s1].unique():
    #for every unique value in s2
    for j in test[s2].unique():
        #calculate and Assign mean to new column corresponding to both unique values of s1 and s2 simultaneously.
        test['Super_mean'][(test[s1]== i) &(test[s2] == str(j))] = train['Height'][(train[s1] == i) & (train[s2] == j)]
# Out:
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\3970622699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Super_mean']=0
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\3970622699.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Super_mean'][(test[s1]== i) &(test[s2] == str(j))] = train['Height'][(train[s1] == i) & (train[s2] == j)]
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_12088\3970622699.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#Calculating mean absolute error
#Super_mean_error = MAE(test['Height'],test['Super_mean'])
#Super_mean_error
